# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## List of tasts
#
# - Add column calory intake per recipe (crawl yummly api)
# - Analyse distribution of lipid/protein/carbs in cuisines
# - Show PCA graph of recipes and flavours
# - Cluster using K-Means

# %% [markdown]
# We will try to answer the following question in our exploratory analysis:
# - What are the most representative ingredients of a cuisine?
# - TFIDF + model -> predidct representative recipes

# %%
import pandas as pd
import json
import os
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.cluster import KMeans
import numpy as np
from sklearn.decomposition import PCA
from IPython.display import display
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import functools

# %%
def load_data(data_folder='data/'):
    '''Helper function to load and concat data'''
    df = None
    for file in os.listdir(data_folder):
        if 'DS_' in file:
            continue
        file_path = os.path.join(data_folder, file)
        with open(file_path) as sd:
            data = json.load(sd)['matches']
        cdf = pd.DataFrame(data)
        cdf['cuisine'] = file.split(".")[0].split("_")[-2]
        df = cdf if df is None else pd.concat([df, cdf])
        #print("For {} cuisine we have {} recipes (from {} recipes)".format(file.split(".")[0], len(cdf[cdf['flavors'].apply(lambda x: not x is None)]), len(cdf)))
    df = df[['flavors', 'id', 'ingredients', 'recipeName', 'cuisine']]
    return df

# %%
df = load_data()
df = df.drop_duplicates(['id'])
df = df.reset_index(drop=True)

# %%
sample = df.sample(n=20)
sample
# Out:
#                                                  flavors  \
# 1650                                                None
# 13286  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 6990                                                None
# 5243   {'piquant': 0.8333333333333334, 'meaty': 0.166...
# 16052                                               None
# 3346   {'piquant': 0.6666666666666666, 'meaty': 0.333...
# 11930                                               None
# 5587                                                None
# 8272                                                None
# 15556  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 8451   {'piquant': 0.0, 'meaty': 0.5, 'bitter': 0.833...
# 9757   {'piquant': 0.0, 'meaty': 0.8333333333333334, ...
# 6449   {'piquant': 0.0, 'meaty': 0.5, 'bitter': 0.5, ...
# 6260   {'piquant': 0.16666666666666666, 'meaty': 0.5,...
# 16225                                               None
# 8787   {'piquant': 0.0, 'meaty': 0.3333333333333333, ...
# 11523  {'piquant': 0.16666666666666666, 'meaty': 0.83...
# 15455  {'piquant': 0.0, 'meaty': 0.6666666666666666, ...
# 1373   {'piquant': 0.0, 'meaty': 0.5, 'bitter': 0.166...
# 2377   {'piquant': 0.6666666666666666, 'meaty': 0.166...
#
#                                                       id  \
# 1650   Cheddar-French-Toast-with-Crab-Hollandaise-162...
# 13286    Grilled-Swedish-Meatball-Kebabs-Food_com-124874
# 6990    Hungarian-Rice-With-Meat-_husos-Rizs_-Recipezaar
# 5243                              Navratan-Korma-1768431
# 16052                         Thai-Chickpea-Stew-1772276
# 3346                         Moroccan-Style-Stew-1309627
# 11930                         Easy-Orange-Chicken-786297
# 5587          Ann-Herrmann_s-Maple-Barbecue-Ribs-1537278
# 8272              Vegetable-Teriyaki-Quinoa-Bowl-1803273
# 15556                 Greek-Chicken-with-Rice-AllRecipes
# 8451   Teriyaki-Chicken-with-Crispy-Soba-Noodles-1833205
# 9757                      Spaghetti-Alla-Caprese-1511533
# 6449   Sun_dried-Tomato-And-Herb_stuffed-Leg-Of-Lamb-...
# 6260              Grilled-Shrimp-Po_Boy-MyRecipes-210904
# 16225                    Shrimp-Thai-Green-Curry-1620370
# 8787                      Tonkatsu-Martha-Stewart-198069
# 11523    Toad-in-the-Hole---Roaring-20_s-Food_com-169856
# 15455                     Greek-Stuffed-Meatballs-968230
# 1373   Chicken-Fricassee-with-Artichokes_-Gnocchi_-an...
# 2377                                  Irish-Stew-1548359
#
#                                              ingredients  \
# 1650   [fat free half and half, large eggs, garlic sa...
# 13286  [ground beef, ground pork, fresh breadcrumbs, ...
# 6990   [cooked white rice, corn oil, yellow onion, re...
# 5243   [carrots, capsicum, potatoes, cauliflower flor...
# 16052  [onions, green bell pepper, zucchini, garlic, ...
# 3346   [ground beef, dried oregano, ground nutmeg, be...
# 11930  [boneless skinless chicken breast halves, oran...
# 5587   [maple syrup, spicy brown mustard, apple cider...
# 8272   [quinoa, water, vegetable oil, tofu, broccoli,...
# 15556  [olive oil, boneless skinless chicken breasts,...
# 8451   [chicken breasts, vegetable oil, sesame oil, s...
# 9757   [spaghetti, tomatoes, mozzarella balls, extra-...
# 6449   [boiling water, sun-dried tomatoes, cooking sp...
# 6260   [jumbo shrimp, olive oil, lemon juice, old bay...
# 16225  [shrimp, lime, ginger, red pepper flakes, salt...
# 8787   [boneless pork loin roast, coarse salt, ground...
# 11523  [eggs, milk, water, mustard, salt, pepper, pla...
# 15455  [eggs, dry bread crumbs, pimento stuffed green...
# 1373   [butter, flour, drumstick, chicken thighs, yel...
# 2377   [olive oil, onions, garlic cloves, dried thyme...
#
#                                               recipeName    cuisine
# 1650          Cheddar French Toast with Crab Hollandaise     french
# 13286                    Grilled Swedish Meatball Kebabs    swedish
# 6990               Hungarian Rice With Meat (Husos Rizs)  hungarian
# 5243                                      Navratan Korma     indian
# 16052                                 Thai Chickpea Stew       thai
# 3346                                 Moroccan-Style Stew   moroccan
# 11930                                Easy Orange Chicken    chinese
# 5587                  Ann Herrmann's Maple Barbecue Ribs   american
# 8272                      Vegetable Teriyaki Quinoa Bowl   japanese
# 15556                            Greek Chicken with Rice      greek
# 8451           Teriyaki Chicken with Crispy Soba Noodles   japanese
# 9757                              Spaghetti Alla Caprese    italian
# 6449       Sun-Dried Tomato and Herb-Stuffed Leg of Lamb   american
# 6260                               Grilled Shrimp Po'Boy   american
# 16225                            Shrimp Thai Green Curry       thai
# 8787                                            Tonkatsu   japanese
# 11523                    Toad in the Hole - Roaring 20's    english
# 15455                            Greek Stuffed Meatballs      greek
# 1373   Chicken Fricassée with Artichokes, Gnocchi, an...     french
# 2377                                          Irish Stew      irish

# %%
# Example of one recipe and the attributes that go with it
a = [print(a) for a in df.sample(n=20).values[0]]
# Out:
# {'piquant': 0.16666666666666666, 'meaty': 0.8333333333333334, 'bitter': 0.6666666666666666, 'sweet': 0.16666666666666666, 'sour': 0.16666666666666666, 'salty': 0.8333333333333334}
# Chicken-Cordon-Bleu-Panini-995152
# ['chicken cutlets', 'flour', 'eggs', 'panko breadcrumbs', 'salt', 'pepper', 'olive oil', 'Ciabatta rolls', 'butter', 'dijon mustard', 'swiss cheese', 'deli ham']
# Chicken Cordon Bleu Panini
# french

# %%
# Listing all the possible ingredients
def get_list_ingredients(df):
    possible_ingredients = {}
    for a  in df['ingredients']:
        for ing in a:
            possible_ingredients[ing] = 1 if(not ing in possible_ingredients) else possible_ingredients[ing]+1
    ing_data = np.array([(key,possible_ingredients[key]) for key in possible_ingredients.keys()])
    df_ing = pd.DataFrame(data={'Ingredient': ing_data[:,0], 'Number of apparition':ing_data[:,1].astype(np.int32)})
    return df_ing

# %%
get_list_ingredients(df).sort_values(by='Number of apparition', ascending=False).head(20).plot(x='Ingredient', y='Number of apparition', kind='bar')

# %% [markdown]
# We notice that a lot of ingredients are written in different ways (e.g. salt and kosher salt).

# %%
list_cuisines = df['cuisine'].unique()
print(list_cuisines)
# Out:
# ['spanish' 'french' 'irish' 'moroccan' 'cuban' 'indian' 'american'
#  'hungarian' 'hawaiian' 'japanese' 'italian' 'mexican' 'english' 'chinese'
#  'swedish' 'german' 'portuguese' 'greek' 'thai']

# %%
df_ing = get_list_ingredients(df.loc[df.cuisine == list_cuisines[-2]])
df_ing.sort_values(by='Number of apparition', ascending=False).head(20).plot(x='Ingredient', y='Number of apparition', kind='bar')

# %%
rank = {0:0,0.16666667 :1,0.33333333:2, 0.5:3,0.66666667:4,0.83333333:5,1:6}
df['flavors'].iloc[0]
df['bitter'] = None
df['salty'] = None
df['piquant']= None
df['sour']= None
df['sweet']= None

def separate_flav_column(x):
    if x.flavors is not None:
        for (k,v)in  x.flavors.items():
            if(v is not None):
                x[k]= rank[round(v,8)]
            else:
                x[k] = v
    return x
df = df.apply(separate_flav_column,axis=1)

# %%
sample = (df.sample(10).reset_index(drop=True))

def draw_radar_graph(df, index,
                    title=''):
    labels = np.array(['piquant', 'meaty', 'bitter', 'sweet', 'sour', 'salty'])
    stats = df.loc[index, labels].values
    angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False) # Set the angle
    
    # close the plot
    stats=np.concatenate((stats,[stats[0]]))  # Closed
    angles=np.concatenate((angles,[angles[0]]))  # Closed
    
    fig= plt.figure()
    ax = fig.add_subplot(111, polar=True)   # Set polar axis
    ax.plot(angles, stats, 'o-', linewidth=2)  # Draw the plot (or the frame on the radar chart)
    ax.fill(angles, stats, alpha=0.25)  #Fulfill the area
    ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
    ax.set_title(title)
    return ax

# %%
sample = df.reset_index(drop=True)


flavors_cuisines = sample.groupby(by='cuisine').agg('mean')
display(flavors_cuisines)
flavors_cuisines[['piquant', 'meaty', 'bitter', 'sweet', 'sour', 'salty']] = flavors_cuisines[['piquant', 'meaty', 'bitter', 'sweet', 'sour', 'salty']].apply(lambda x: (x-x.min())/(x.max()-x.min()))

for cuisine in flavors_cuisines.index:
    draw_radar_graph(flavors_cuisines, cuisine, title=cuisine)
# Out:
#               bitter     meaty   piquant     salty      sour     sweet
# cuisine
# american    2.541478  2.544495  1.835596  2.843137  2.494721  1.345400
# chinese     3.396149  2.583219  1.364512  4.001376  2.583219  1.654746
# cuban       2.154265  2.473684  1.885662  2.765880  3.455535  1.279492
# english     2.239344  2.608197  1.470492  2.644262  2.108197  1.078689
# french      2.033094  2.483453  0.732374  2.351079  2.064748  1.060432
# german      2.482005  2.438303  0.791774  3.196658  2.370180  1.223650
# greek       2.454054  2.218919  0.668919  2.885135  2.979730  1.112162
# hawaiian    2.941620  1.967985  1.602637  3.838041  3.913371  2.608286
# hungarian   1.714567  1.872047  2.187008  2.169291  2.797244  1.116142
# indian      2.274419  2.071318  2.728682  2.392248  2.886822  1.170543
# irish       1.847896  1.555016  1.343042  2.084142  3.100324  1.061489
# italian     2.864907  2.602484  0.571429  3.172360  2.080745  1.253106
# japanese    3.700730  2.436131  0.788321  4.124088  1.970803  1.406934
# mexican     3.230519  2.527597  3.641234  3.639610  2.676948  1.214286
# moroccan    2.032832  2.231190  1.575923  2.322845  2.816689  1.290014
# portuguese  2.072539  2.393782  1.683938  2.248705  2.896373  1.051813
# spanish     1.832880  1.876359  2.366848  2.330163  3.455163  1.058424
# swedish     2.078091  2.722343  1.388286  3.277657  1.295011  1.158351
# thai        3.204461  2.249071  2.315985  3.548327  3.208178  1.444238

# %%
df[df.recipeName.str.contains('Kung')]
print(len(df[(df.piquant >=4) & (df.cuisine == 'chinese')]),len(df[(df.cuisine == 'chinese')]))
# Out:
# 117 989

# %%
import string
#Create a set containing all ingredients
ingr = set()
df.ingredients.apply(lambda x: [ingr.add(y) for y in x])
#converting ingredients to text

text_ingredients = df.ingredients.apply(lambda l_ingredients : functools.reduce(lambda acc,x : acc +' ' +x,map(lambda ingred: ingred.translate(str.maketrans('', '', string.whitespace)),l_ingredients)))

# %%
# Vectorize recipes
vectorizer = TfidfVectorizer(stop_words=None)
vectors = vectorizer.fit_transform(text_ingredients)

# %%
df.set_index
cuisines_label = pd.get_dummies(df.cuisine)
cuisines_classes = cuisines_label.columns.tolist()
df.cuisine = df.cuisine.astype('category')

'''
for cuisine in cuisines_classes:
    logistic = LogisticRegression()
    logistic.fit(vectors,cuisines_label[cuisine])
    print(logistic.predict_proba(vectors))
    recipes_to_cuisine.loc[:,cuisine]= logistic.predict_proba(vectors)
'''
logistic = LogisticRegression(multi_class= 'multinomial',solver='lbfgs')
logistic.fit(vectors,df.cuisine.astype('category').cat.codes)
predicted_probas = logistic.predict_proba(vectors)

# %%
recipes_to_cuisine_1 = pd.DataFrame(predicted_probas,columns =  df.cuisine.cat.categories)
recipes_to_cuisine_1 = pd.concat([df.id,recipes_to_cuisine_1],axis = 1)
recipes_to_cuisine_1 = recipes_to_cuisine_1.set_index('id',drop = True)
recipes_to_cuisine_1['classes'] = logistic.predict(vectors)

# %%
def apply_func(x):
    temp =recipes_to_cuisine_1.loc[x.id,'classes'].astype(int)
    return (recipes_to_cuisine_1.loc[x.id,x.cuisine] >= 0.6) and (df.cuisine.cat.categories.tolist()[temp] == x.cuisine)
df['keep'] = df.apply(apply_func  ,axis = 1)

# %%
df[df['keep']]
# Out:
#        bitter  cuisine                                            flavors  \
# 0         2.0  spanish  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 1         NaN  spanish                                               None
# 3         2.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4         1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 5         1.0  spanish  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 6         4.0  spanish  {'piquant': 0.3333333333333333, 'meaty': 0.166...
# 7         NaN  spanish                                               None
# 9         3.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 10        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 11        2.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 12        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 15        2.0  spanish  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 16        1.0  spanish  {'piquant': 0.5, 'meaty': 0.6666666666666666, ...
# 17        3.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 18        1.0  spanish  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 19        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 20        3.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 24        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 27        NaN  spanish                                               None
# 28        3.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.666...
# 30        5.0  spanish  {'piquant': 0.8333333333333334, 'meaty': 0.333...
# 31        NaN  spanish                                               None
# 32        NaN  spanish                                               None
# 33        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 34        1.0  spanish  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 35        NaN  spanish                                               None
# 36        NaN  spanish                                               None
# 37        NaN  spanish                                               None
# 38        NaN  spanish                                               None
# 39        4.0  spanish  {'piquant': 0.6666666666666666, 'meaty': 0.333...
# ...       ...      ...                                                ...
# 16555     NaN     thai                                               None
# 16556     NaN     thai                                               None
# 16557     3.0     thai  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 16558     1.0     thai  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 16559     NaN     thai                                               None
# 16560     4.0     thai  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 16561     NaN     thai                                               None
# 16563     NaN     thai                                               None
# 16564     NaN     thai                                               None
# 16565     NaN     thai                                               None
# 16566     3.0     thai  {'piquant': 0.6666666666666666, 'meaty': 0.333...
# 16567     3.0     thai  {'piquant': 0.16666666666666666, 'meaty': 0.66...
# 16568     NaN     thai                                               None
# 16569     NaN     thai                                               None
# 16570     NaN     thai                                               None
# 16571     1.0     thai  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 16572     5.0     thai  {'piquant': 0.3333333333333333, 'meaty': 0.166...
# 16573     5.0     thai  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# 16574     NaN     thai                                               None
# 16575     1.0     thai  {'piquant': 0.8333333333333334, 'meaty': 0.166...
# 16576     NaN     thai                                               None
# 16577     NaN     thai                                               None
# 16578     1.0     thai  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 16579     NaN     thai                                               None
# 16580     5.0     thai  {'piquant': 0.3333333333333333, 'meaty': 0.166...
# 16581     4.0     thai  {'piquant': 0.16666666666666666, 'meaty': 0.66...
# 16582     NaN     thai                                               None
# 16583     NaN     thai                                               None
# 16584     NaN     thai                                               None
# 16585     5.0     thai  {'piquant': 0.0, 'meaty': 0.16666666666666666,...
#
#                                                       id  \
# 0                            Easy-Seafood-Paella-2077829
# 1      Skillet-Grilled-Seafood-and-Chorizo-Paella_-21...
# 3                                  Classic-Paella-898818
# 4               One-Pot-Spanish-Chicken-and-Rice-2237989
# 5                            Portuguese-fish-stew-306395
# 6                        Portuguese-Seafood-Stew-2139944
# 7                                          Paella-578302
# 9       Spanish-Chicken-with-Chorizo-and-Potatoes-679012
# 10                               Mushroom-Paella-2040267
# 11     Spanish-Chicken-with-Chorizo-and-Potatoes-2074171
# 12     Spanish_Style-Chicken-with-Saffron-Rice-_Arroz...
# 15                                        Paella-1457001
# 16                          Spanish-Chicken-Stew-1808471
# 17      Spanish-Chicken-with-Chorizo-and-Potatoes-982885
# 18                     Tomato-paella-with-chorizo-345809
# 19                      Prawn-And-Chorizo-Paella-1727793
# 20      SPANISH-CHICKEN-WITH-CHORIZO-AND-POTATOES-569892
# 24                    One-Skillet-Healthy-Paella-1185025
# 27     Lentejas-con-Chorizo-_Spanish-Lentil-Soup_-604297
# 28                         Quick-Paella-Epicurious-54432
# 30                         Quinoa-Chorizo-Paella-1209498
# 31               Portuguese-style-chicken-one-pot-349026
# 32      Spanish-Spaghetti-with-Shrimp-and-Chorizo-685914
# 33     Lentejas-Caseras-_-Traditional-Spanish-Lentils...
# 34                             Vegetarian-Paella-1016735
# 35                   Braised-squid-with-chickpeas-334477
# 36                          Cheats-Chorizo-Paella-681122
# 37     Spanish-Chicken-With-Chorizo-and-Potatoes-1536928
# 38                          Portuguese-Fish-Stew-1759615
# 39        Simple-Vegan-Spanish-Rice-with-Chorizo-1009415
# ...                                                  ...
# 16555  Thai-Red-Curry-with-Shrimp-and-Rice-Noodles-16...
# 16556                  One-Pot-Thai-Shrimp-Pasta-1490884
# 16557                            Thai-Fried-Rice-1164164
# 16558         Thai-Coconut-Red-Curry-with-Prawns-1440143
# 16559                     Thai-Red-Curry-Noodles-1397498
# 16560              30-Minute-Sticky-Thai-Chicken-1428404
# 16561  Tom-Kha-Gai-Soup-Thai-Chicken-in-Coconut-Milk-...
# 16563                             Vegan-Pad-Thai-1498688
# 16564             Tofu-Stir-fried-with-Thai-Basil-998362
# 16565  Thai-Chicken-Curry-with-Eggplant_-Baby-Bok-Cho...
# 16566  Thai-Massaman-Curry-with-Sweet-Potatoes-and-To...
# 16567  Thai-Turkey-Meatballs-with-Coconut-Curry-Sauce...
# 16568  Thai-Style-Marinated-Flank-Steak-and-Herb-Sala...
# 16569                         Thai-Chicken-Curry-1159175
# 16570  Easy-Thai-Coconut-Noodles-with-Shrimp-or-Chick...
# 16571                 Thai-Shrimp-and-Basil-Curry-749295
# 16572                          Thai-Basil-Shrimp-1820013
# 16573                     Thai-Cashew-Chicken-Allrecipes
# 16574                     Thai-Red-Chicken-Curry-2067682
# 16575  Vegan-Thai-Green-Curry-from-scratch-with-Sweet...
# 16576                 Easy-Thai-Red-Curry-Shrimp-1936110
# 16577                    Thai-Coconut-Curry-Soup-1989203
# 16578        Thai-Chicken-With-Basil-Stir-Fry-Allrecipes
# 16579               Thai-Mango-and-Chicken-Curry-2052367
# 16580              Larb-Gai-Thai-Chicken-Skillet-2057774
# 16581         Fish-Sticks-with-Thai-Peanut-Sauce-1183636
# 16582  Grain-free-Thai-Chicken-Meatballs-with-Coconut...
# 16583       Thai-Coconut-Chicken-Red-Lentil-Soup-1796917
# 16584                        Thai-Mushroom-Curry-1801070
# 16585                     Thai-Red-Curry-Mussels-1781402
#
#                                              ingredients  meaty  piquant  \
# 0      [lobster tails, water, olive oil, yellow onion...    1.0      4.0
# 1      [olive oil, sweet onion, garlic, spanish chori...    NaN      NaN
# 3      [extra-virgin olive oil, skinless chicken brea...    1.0      1.0
# 4      [olive oil, chicken thighs, salt, pepper, onio...    1.0      1.0
# 5      [plum tomatoes, savoy cabbage, extra-virgin ol...    1.0      3.0
# 6      [littleneck clams, large shrimp, scallops, ext...    1.0      2.0
# 7      [saffron, chicken thighs, large shrimp, ground...    NaN      NaN
# 9      [olive oil, chicken thighs, chorizo sausage, b...    5.0      5.0
# 10     [cremini, dried porcini mushrooms, olive oil, ...    1.0      1.0
# 11     [olive oil, chicken thighs, chorizo, potatoes,...    5.0      5.0
# 12     [chicken, olive oil, onions, red bell pepper, ...    1.0      1.0
# 15     [paella rice, chorizo, boneless skinless chick...    1.0      4.0
# 16     [olive oil, chicken thighs, chorizo, onions, g...    4.0      3.0
# 17     [olive oil, chicken thighs, chorizo sausage, b...    5.0      5.0
# 18     [chicken broth, tomatoes, salt, ground black p...    1.0      3.0
# 19     [gluten, prawns, garlic cloves, yellow onion, ...    1.0      1.0
# 20     [olive oil, chicken thighs, chorizo, new potat...    5.0      5.0
# 24     [chicken breasts, jumbo shrimp, coconut oil, b...    1.0      1.0
# 27     [lentils, chorizo, garlic, carrots, potatoes, ...    NaN      NaN
# 28     [chorizo, olive oil, rice, artichoke hearts, r...    4.0      5.0
# 30     [quinoa, chorizo, fresh tomatoes, onions, papr...    2.0      5.0
# 31     [red bell pepper, bone in chicken thighs, salt...    NaN      NaN
# 32     [jumbo shrimp, chorizo sausage, thin spaghetti...    NaN      NaN
# 33     [green lentil, tomatoes, vegetable stock, gree...    1.0      1.0
# 34     [saffron threads, warm water, olive oil, onion...    1.0      1.0
# 35     [squid, chickpeas, garlic bulb, smoked paprika...    NaN      NaN
# 36     [olive oil, garlic, onions, chorizo sausage, m...    NaN      NaN
# 37     [olive oil, chicken thighs, chorizo, new potat...    NaN      NaN
# 38     [chorizo sausage, olive oil, onions, garlic cl...    NaN      NaN
# 39     [extra-virgin olive oil, chorizo, garlic, onio...    2.0      4.0
# ...                                                  ...    ...      ...
# 16555  [virgin coconut oil, Thai red curry paste, gar...    NaN      NaN
# 16556  [linguini, chicken stock, garlic, soy sauce, f...    NaN      NaN
# 16557  [jasmine rice, coconut milk, chicken, green on...    1.0      3.0
# 16558  [vegetable oil, Thai red curry paste, coconut ...    1.0      1.0
# 16559  [rice noodles, eggplant, broccoli, ginger, bas...    NaN      NaN
# 16560  [egg whites, corn starch, rice vinegar, vegeta...    1.0      3.0
# 16561  [chicken breasts, coconut milk, water, galanga...    NaN      NaN
# 16563  [shiitake, rice stick noodles, oil, lemongrass...    NaN      NaN
# 16564  [firm tofu, garlic, chillies, thai basil, coco...    NaN      NaN
# 16565  [long grain brown rice, safflower oil, garlic,...    NaN      NaN
# 16566  [coconut milk, curry paste, sweet potatoes, fr...    2.0      4.0
# 16567  [ground turkey, green onions, fresh ginger, ci...    4.0      1.0
# 16568  [palm sugar, water, fish sauce, lime juice, ga...    NaN      NaN
# 16569  [light coconut milk, red curry paste, brown su...    NaN      NaN
# 16570  [rice noodles, large shrimp, coconut milk, chi...    NaN      NaN
# 16571  [vegetable oil, broccoli, red bell pepper, fre...    1.0      1.0
# 16572  [shrimp, salt, pepper, red bell pepper, low so...    1.0      2.0
# 16573  [soy sauce, fish sauce, hot pepper sauce, garl...    1.0      3.0
# 16574  [red curry paste, shallots, vegetable oil, bro...    NaN      NaN
# 16575  [coriander seeds, garlic, thai chile, serrano ...    1.0      5.0
# 16576  [onions, garlic, cooking oil, Thai red curry p...    NaN      NaN
# 16577  [onions, green pepper, jalapeno chilies, fresh...    NaN      NaN
# 16578  [jasmine rice, water, coconut milk, soy sauce,...    1.0      1.0
# 16579  [vegetable oil, clove, ginger, onions, Thai re...    NaN      NaN
# 16580  [cauliflower, coconut oil, ground chicken, gre...    1.0      2.0
# 16581  [tilapia fillets, panko breadcrumbs, coconut m...    4.0      1.0
# 16582  [dark meat, almond flour, scallions, garlic, f...    NaN      NaN
# 16583  [olive oil, onions, red bell pepper, garlic, y...    NaN      NaN
# 16584  [straw mushrooms, coconut milk, chicken stock,...    NaN      NaN
# 16585  [mussels, peanut oil, garlic, minced ginger, T...    1.0      0.0
#
#                                               recipeName  salty  sour  sweet  \
# 0                                    Easy Seafood Paella    1.0   1.0    1.0
# 1            Skillet Grilled Seafood and Chorizo Paella.    NaN   NaN    NaN
# 3                                         Classic Paella    1.0   4.0    1.0
# 4                       One Pot Spanish Chicken and Rice    1.0   5.0    1.0
# 5                                   Portuguese Fish Stew    2.0   3.0    1.0
# 6                                Portuguese Seafood Stew    1.0   4.0    1.0
# 7                                                 Paella    NaN   NaN    NaN
# 9              Spanish Chicken with Chorizo and Potatoes    3.0   3.0    1.0
# 10                                       Mushroom Paella    1.0   4.0    1.0
# 11             Spanish Chicken with Chorizo and Potatoes    3.0   4.0    1.0
# 12     Spanish-Style Chicken with Saffron Rice (Arroz...    1.0   4.0    1.0
# 15                                                Paella    3.0   3.0    1.0
# 16                                  Spanish Chicken Stew    1.0   2.0    1.0
# 17             Spanish Chicken with Chorizo and Potatoes    3.0   3.0    1.0
# 18                            Tomato Paella with Chorizo    1.0   2.0    1.0
# 19                              Prawn And Chorizo Paella    1.0   5.0    1.0
# 20             SPANISH CHICKEN WITH CHORIZO AND POTATOES    3.0   3.0    1.0
# 24                            One-Skillet Healthy Paella    1.0   3.0    1.0
# 27            Lentejas con Chorizo (Spanish Lentil Soup)    NaN   NaN    NaN
# 28                                          Quick Paella    4.0   1.0    1.0
# 30                                 Quinoa Chorizo Paella    5.0   4.0    1.0
# 31                      Portuguese-Style Chicken One-Pot    NaN   NaN    NaN
# 32             Spanish Spaghetti with Shrimp and Chorizo    NaN   NaN    NaN
# 33        Lentejas Caseras ~ Traditional Spanish Lentils    1.0   4.0    1.0
# 34                                     Vegetarian Paella    3.0   5.0    1.0
# 35                          Braised Squid with Chickpeas    NaN   NaN    NaN
# 36                                Cheat’s Chorizo Paella    NaN   NaN    NaN
# 37             Spanish Chicken With Chorizo and Potatoes    NaN   NaN    NaN
# 38                                  Portuguese Fish Stew    NaN   NaN    NaN
# 39                Simple Vegan Spanish Rice with Chorizo    4.0   4.0    1.0
# ...                                                  ...    ...   ...    ...
# 16555        Thai Red Curry with Shrimp and Rice Noodles    NaN   NaN    NaN
# 16556                          One Pot Thai Shrimp Pasta    NaN   NaN    NaN
# 16557                                    Thai Fried Rice    4.0   4.0    1.0
# 16558                 Thai Coconut Red Curry with Prawns    3.0   5.0    1.0
# 16559                             Thai Red Curry Noodles    NaN   NaN    NaN
# 16560                      30 Minute Sticky Thai Chicken    5.0   5.0    3.0
# 16561    Tom Kha Gai Soup – Thai Chicken in Coconut Milk    NaN   NaN    NaN
# 16563                                     Vegan Pad Thai    NaN   NaN    NaN
# 16564                    Tofu Stir-fried with Thai Basil    NaN   NaN    NaN
# 16565  Thai Chicken Curry with Eggplant, Baby Bok Cho...    NaN   NaN    NaN
# 16566   Thai Massaman Curry with Sweet Potatoes and Tofu    2.0   4.0    2.0
# 16567     Thai Turkey Meatballs with Coconut Curry Sauce    4.0   2.0    1.0
# 16568    Thai-Style Marinated Flank Steak and Herb Salad    NaN   NaN    NaN
# 16569                                 Thai Chicken Curry    NaN   NaN    NaN
# 16570  Easy Thai Coconut Noodles with Shrimp or Chick...    NaN   NaN    NaN
# 16571                        Thai Shrimp and Basil Curry    1.0   5.0    1.0
# 16572                                  Thai Basil Shrimp    5.0   5.0    1.0
# 16573                                Thai Cashew Chicken    5.0   1.0    1.0
# 16574                             Thai Red Chicken Curry    NaN   NaN    NaN
# 16575  Vegan Thai Green Curry from scratch with Sweet...    1.0   3.0    2.0
# 16576                         Easy Thai Red Curry Shrimp    NaN   NaN    NaN
# 16577                            Thai Coconut Curry Soup    NaN   NaN    NaN
# 16578                   Thai Chicken with Basil Stir Fry    3.0   1.0    1.0
# 16579                       Thai Mango and Chicken Curry    NaN   NaN    NaN
# 16580                      Larb Gai Thai Chicken Skillet    5.0   5.0    1.0
# 16581                 Fish Sticks with Thai Peanut Sauce    4.0   4.0    2.0
# 16582  Grain-free Thai Chicken Meatballs with Coconut...    NaN   NaN    NaN
# 16583               Thai Coconut Chicken Red Lentil Soup    NaN   NaN    NaN
# 16584                                Thai Mushroom Curry    NaN   NaN    NaN
# 16585                             Thai Red Curry Mussels    5.0   3.0    1.0
#
#        keep
# 0      True
# 1      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 9      True
# 10     True
# 11     True
# 12     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 24     True
# 27     True
# 28     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# ...     ...
# 16555  True
# 16556  True
# 16557  True
# 16558  True
# 16559  True
# 16560  True
# 16561  True
# 16563  True
# 16564  True
# 16565  True
# 16566  True
# 16567  True
# 16568  True
# 16569  True
# 16570  True
# 16571  True
# 16572  True
# 16573  True
# 16574  True
# 16575  True
# 16576  True
# 16577  True
# 16578  True
# 16579  True
# 16580  True
# 16581  True
# 16582  True
# 16583  True
# 16584  True
# 16585  True
#
# [10772 rows x 12 columns]

# %%
print(len(df[df['keep']]))
flavors_cuisines = df[df['keep']].groupby(by='cuisine').agg('mean')
display(flavors_cuisines)
flavors_cuisines[['piquant', 'meaty', 'bitter', 'sweet', 'sour', 'salty']] = flavors_cuisines[['piquant', 'meaty', 'bitter', 'sweet', 'sour', 'salty']].apply(lambda x: (x-x.min())/(x.max()-x.min()))

for cuisine in flavors_cuisines.index:
    draw_radar_graph(flavors_cuisines, cuisine, title=cuisine)
# Out:
# 10772
#               bitter     meaty   piquant     salty      sour     sweet  keep
# cuisine
# american    2.446886  2.582418  2.021978  2.750916  2.505495  1.439560  True
# chinese     3.451839  2.639229  1.437828  4.084063  2.513135  1.623468  True
# cuban       2.138889  2.540123  1.660494  2.731481  3.537037  1.246914  True
# english     2.240000  3.005714  1.600000  2.777143  1.880000  1.074286  True
# french      1.932249  2.460705  0.653117  2.097561  2.037940  1.035230  True
# german      2.622680  2.367010  0.690722  3.334021  2.461856  1.263918  True
# greek       2.457377  2.168852  0.657377  2.936066  2.963934  1.093443  True
# hawaiian    2.979167  1.945312  1.658854  3.950521  4.239583  2.791667  True
# hungarian   1.649701  1.895210  2.338323  2.125749  2.634731  1.137725  True
# indian      2.292593  2.011111  2.822222  2.361111  2.990741  1.177778  True
# irish       1.678873  1.312676  1.261972  1.876056  3.346479  1.047887  True
# italian     3.092857  2.742857  0.507143  3.288095  1.930952  1.290476  True
# japanese    3.765517  2.400000  0.629885  4.172414  1.914943  1.409195  True
# mexican     3.382022  2.465169  3.773034  3.804494  2.620225  1.229213  True
# moroccan    1.969697  2.244207  1.540107  2.260250  2.752228  1.313725  True
# portuguese  2.000000  3.142857  1.857143  2.285714  2.714286  1.000000  True
# spanish     1.798793  1.774648  2.545272  2.348089  3.444668  1.036217  True
# swedish     1.932886  2.848993  1.395973  3.369128  1.134228  1.087248  True
# thai        3.221219  2.203160  2.318284  3.591422  3.268623  1.437923  True

# %%
logistic.coef_[0,np.argsort(-logistic.coef_[0])][:20]
# Out:
# array([ 4.67045375,  3.41890914,  3.26877088,  3.11574884,  2.9441137 ,
#         2.85975481,  2.85649113,  2.84784472,  2.8319112 ,  2.68944947,
#         2.59585752,  2.51226948,  2.47072706,  2.4682582 ,  2.45764198,
#         2.36211784,  2.35944476,  2.33493933,  2.33309603,  2.32113863])

# %%
import matplotlib.ticker as ticker

top_20 = list()
#Top ingredients in every cuisine
f,ax = plt.subplots(19,1)
f.set_size_inches(20,300)
for i in range(19):
    top_features = np.argsort(-logistic.coef_[i])[:20]
    top_20.append(top_features)
    features_names = vectorizer.get_feature_names()


    ax[i].barh(range(20), logistic.coef_[i,top_features], align='center')
    ax[i].set_yticks(np.arange(20))
    ax[i].set_yticklabels([features_names[i] for i in top_features])
    ax[i].set_xlabel('Feature Importance')
    ax[i].set_title(df.cuisine.cat.categories[i])
    ax[i].tick_params(direction='out', length=6, width=4)

# %%
vectorizer.get_feature_names()
# Out:
# ['10oz',
#  '14',
#  '15groundturkey',
#  '1inchthick',
#  '21',
#  '2to3lb',
#  '33',
#  '40',
#  '50',
#  '5oz',
#  '85',
#  '95',
#  '98',
#  '99',
#  'a1steaksauce',
#  'abckecapmanis',
#  'aburaage',
#  'accentseasoning',
#  'achiote',
#  'achiotepaste',
#  'achiotepowder',
#  'acorn',
#  'acornsquash',
#  'actingbakingpowder',
#  'activedryyeast',
#  'addedblackbeans',
#  'addeddicedtomatoes',
#  'adobo',
#  'adoboall',
#  'adobosauce',
#  'adoboseasoning',
#  'agar',
#  'agavenectar',
#  'agedbalsamicvinegar',
#  'agedmanchegocheese',
#  'agedsherryvinegar',
#  'ahi',
#  'ahitunasteaks',
#  'aioli',
#  'ajimirin',
#  'ajinomoto',
#  'ajvar',
#  'ajwain',
#  'akamiso',
#  'alaskahalibutfillets',
#  'albacore',
#  'alcohol',
#  'ale',
#  'aleppo',
#  'aleppopepper',
#  'alfalfasprouts',
#  'alfredo',
#  'alfredosauce',
#  'alfredosaucemix',
#  'all',
#  'allbeefhotdogs',
#  'allnatural',
#  'allnaturalreducedsodiumchickenbroth',
#  'allpurposeseasoning',
#  'allspice',
#  'allspiceberries',
#  'almondbutter',
#  'almondflour',
#  'almondmeal',
#  'almondmilk',
#  'almonds',
#  'amba',
#  'amberale',
#  'amchur',
#  'americancheese',
#  'americancheeseslices',
#  'amontilladosherry',
#  'anaheimchile',
#  'anardana',
#  'ancho',
#  'anchochilepepper',
#  'anchochiligroundpepper',
#  'anchopowder',
#  'anchovies',
#  'anchovyfilets',
#  'anchovyfillets',
#  'anchovypaste',
#  'andouillechickensausage',
#  'andouillesausage',
#  'andouillesausagelinks',
#  'angelhair',
#  'angosturaaromaticbitters',
#  'angus',
#  'animalfats',
#  'anise',
#  'aniseliqueur',
#  'aniseseed',
#  'anjoupears',
#  'annatto',
#  'annattooil',
#  'annattopowder',
#  'annattoseeds',
#  'aonori',
#  'applebrandy',
#  'applebutter',
#  'applecider',
#  'applecidervinegar',
#  'applegateham',
#  'applejelly',
#  'applejuice',
#  'applejuiceconcentrate',
#  'apples',
#  'applesauce',
#  'appleschnapps',
#  'applewoodsmokedbacon',
#  'apricotfruitspread',
#  'apricothalves',
#  'apricotjam',
#  'apricotjelly',
#  'apricotnectar',
#  'apricotpreserves',
#  'apricotpuree',
#  'apricots',
#  'arame',
#  'arbolchile',
#  'arboriorice',
#  'arcticchar',
#  'armagnac',
#  'arrabbiatasauce',
#  'arrowroot',
#  'arrowrootflour',
#  'arrowrootpowder',
#  'arrowrootstarch',
#  'artichokebottoms',
#  'artichokehearts',
#  'artichokes',
#  'artisanblends',
#  'arugula',
#  'asafoetida',
#  'asafoetidapowder',
#  'asiago',
#  'asian',
#  'asianbarbecuesauce',
#  'asianbasil',
#  'asianchilepaste',
#  'asianchilisauce',
#  'asianeggplants',
#  'asianfishsauce',
#  'asianherb',
#  'asiannoodles',
#  'asianpears',
#  'asianricenoodles',
#  'asiansweetchilisauce',
#  'asparagus',
#  'asparagusspears',
#  'asparagustips',
#  'assortedfreshvegetables',
#  'atar',
#  'athenostraditionalcrumbledfetacheese',
#  'atlanticcodfillets',
#  'aujus',
#  'aujusmix',
#  'avocado',
#  'avocadooil',
#  'avocadoslices',
#  'azukibean',
#  'baba',
#  'babyartichokes',
#  'babyarugula',
#  'babybackribs',
#  'babybeetroots',
#  'babybeets',
#  'babybokchoy',
#  'babycalamari',
#  'babycapers',
#  'babycarrots',
#  'babycorn',
#  'babyeggplants',
#  'babyfennel',
#  'babygemlettuce',
#  'babygreens',
#  'babykale',
#  'babyleaflettuce',
#  'babylimabeans',
#  'babyportobellomushrooms',
#  'babypotatoes',
#  'babyradishes',
#  'babyspinach',
#  'babyspinachleaves',
#  'babytatsoi',
#  'babyturnips',
#  'babyzucchini',
#  'bacardi',
#  'backbacon',
#  'backbaconrashers',
#  'backribs',
#  'bacon',
#  'baconbits',
#  'baconcubes',
#  'bacondrippings',
#  'baconfat',
#  'bacongrease',
#  'baconpieces',
#  'baconranchdressing',
#  'baconslices',
#  'badiacompleteseasoning',
#  'baguette',
#  'baharatspicemix',
#  'baicai',
#  'bakedbeans',
#  'bakeddeliham',
#  'bakedham',
#  'bakedpizzacrust',
#  'bakedpizzacrusts',
#  'bakedpotato',
#  'bakedtortillachips',
#  'bakingapples',
#  'bakingmix',
#  'bakingpotatoes',
#  'bakingpowder',
#  'bakingsoda',
#  'balsamicobianco',
#  'balsamicreduction',
#  'balsamicvinaigrette',
#  'balsamicvinaigrettesaladdressing',
#  'balsamicvinegar',
#  'bambooleaves',
#  'bambooshoots',
#  'bananablossom',
#  'bananaleaves',
#  'bananapeppers',
#  'bananas',
#  'banger',
#  'baobabfruitpowder',
#  'barbecuedpork',
#  'barbecuerub',
#  'barbecuesauce',
#  'barbecueseasoning',
#  'barillaoven',
#  'barley',
#  'barleymiso',
#  'barramundi',
#  'barramundifillets',
#  'bartlettpears',
#  'base',
#  'basil',
#  'basilikum',
#  'basilleaves',
#  'basiloliveoil',
#  'basilpesto',
#  'basilsauce',
#  'basmati',
#  'basmatirice',
#  'bass',
#  'bassfillets',
#  'baton',
#  'batter',
#  'bauernwurst',
#  'bavarianswisscheese',
#  'bawanggoreng',
#  'bayleaf',
#  'bayleaves',
#  'bayscallops',
#  'bbqsauce',
#  'bbqseasoning',
#  'bcurrypowder',
#  'beancurd',
#  'beancurdskins',
#  'beancurdstick',
#  'beanpaste',
#  'beans',
#  'beansauce',
#  'beansprouts',
#  'beanthreads',
#  'beateneggs',
#  'beef',
#  'beefbase',
#  'beefbonelesschucksteak',
#  'beefbonelessmeatstew',
#  'beefbones',
#  'beefbouillon',
#  'beefbouillongranules',
#  'beefbouillonpowder',
#  'beefbrisket',
#  'beefbroth',
#  'beefconsomme',
#  'beefdemi',
#  'beefdrippings',
#  'beeffat',
#  'beeffillet',
#  'beefflavoredbouilloncube',
#  'beefforstew',
#  'beefgravy',
#  'beefhotdogs',
#  'beefhotlinks',
#  'beefjerky',
#  'beefkidney',
#  'beefliver',
#  'beefmarrow',
#  'beefmeatballs',
#  'beefpastaskilletmeal',
#  'beefribroast',
#  'beefribs',
#  'beefroast',
#  'beefround',
#  'beefrump',
#  'beefrumpsteaks',
#  'beefsausage',
#  'beefschnitzel',
#  'beefseasoning',
#  'beefshank',
#  'beefshin',
#  'beefshortribs',
#  'beefshoulder',
#  'beefshoulderroast',
#  'beefsirloin',
#  'beefsmokedsausage',
#  'beefsteak',
#  'beefsteaktomatoes',
#  'beefstew',
#  'beefstewmeat',
#  'beefstock',
#  'beefstockcubes',
#  'beefstrips',
#  'beeftenderloin',
#  'beeftenderloinfillets',
#  'beeftenderloinsteaks',
#  'beeftendons',
#  'beeftongue',
#  'beer',
#  'beetjuice',
#  'beets',
#  'bellpepper',
#  'belugalentil',
#  'bengalgram',
#  'bengali5spice',
#  'benishoga',
#  'berries',
#  'bertolli',
#  'bertollifourcheesrosasauc',
#  'bertolligarlicalfredosauce',
#  'bertollioliveoil',
#  'bertollitomato',
#  'bertollivineyardpremiumcollectmarinarawithburgundiwinesauc',
#  'bhaji',
#  'bhindi',
#  'bibblettuce',
#  'bicarbonateofsoda',
#  'bingcherries',
#  'birdchile',
#  'birdpepper',
#  'biryanimasala',
#  'biscuitbakingmix',
#  'biscuitdough',
#  'biscuitmix',
#  'biscuits',
#  'bisquick',
#  'bisquickbakingmix',
#  'bisto',
#  'bistogravymix',
#  'bitterorangejuice',
#  'bittersweetchocolate',
#  'bittersweetchocolatechips',
#  'black',
#  'blackbass',
#  'blackbeanandcornsalsa',
#  'blackbeans',
#  'blackbeansauce',
#  'blackbeanstirfrysauce',
#  'blackberries',
#  'blackberrypreserves',
#  'blackcardamompods',
#  'blackchickpeas',
#  'blackcod',
#  'blackcodfillets',
#  'blackcuminseeds',
#  'blackeningseasoning',
#  'blackforestham',
#  'blackfungus',
#  'blackgarlic',
#  'blackgram',
#  'blackgrapes',
#  'blacklentil',
#  'blackmustardseeds',
#  'blackolives',
#  'blackonionseeds',
#  'blackpepper',
#  'blackpeppercorns',
#  'blackpudding',
#  'blackrice',
#  'blackricevinegar',
#  'blacksalt',
#  'blacksesameseeds',
#  'blackstrapmolasses',
#  'blacktreacle',
#  'blacktruffles',
#  'blackvinegar',
#  'bladeporksteaks',
#  'bladeroast',
#  'bladesteak',
#  'blanchedalmondflour',
#  'blanchedalmonds',
#  'blanchedhazelnuts',
#  'blanchedsliveredalmonds',
#  'bloodorange',
#  'bloodorangejuice',
#  'bloodsausage',
#  'blue',
#  'bluecheese',
#  'bluecheesedressing',
#  'bluecrabs',
#  'boar',
#  'bobevansitaliansausage',
#  'bocconcini',
#  'bockwurst',
#  'boiledegg',
#  'boiledeggs',
#  'boiledham',
#  'boilingonions',
#  'boilingpotatoes',
#  'boilingwater',
#  'bokchoy',
#  'bokchoysum',
#  'bolillo',
#  'bombarice',
#  'bone',
#  'bonebroth',
#  'bonedlambshoulder',
#  'bonedtroutfillets',
#  'bonefatfree',
#  'bonegreekvinaigrettedressing',
#  'bonein',
#  'bonein33',
#  'boneinchickenthighs',
#  'boneinlesssodiumham',
#  'boneinskinlesschickenthigh',
#  'boneitaliandressing',
#  'boneless',
#  'bonelessbeefchuck',
#  'bonelessbeefchuckeyeroast',
#  'bonelessbeefchuckpotroast',
#  'bonelessbeefchuckroast',
#  'bonelessbeefroast',
#  'bonelessbeefroundsteak',
#  'bonelessbeefshortribs',
#  'bonelessbeefsirloinsteak',
#  'bonelessbeeftoproundsteak',
#  'bonelesscentercutporkchops',
#  'bonelesschicken',
#  'bonelesschickenbreast',
#  'bonelesschickenbreasthalves',
#  'bonelesschickencutlet',
#  'bonelesschickenthighs',
#  'bonelesschuckroast',
#  'bonelesscodfillets',
#  'bonelesscountryporkribs',
#  'bonelessduckbreast',
#  'bonelessduckbreasthalves',
#  'bonelessham',
#  'bonelesslamb',
#  'bonelessmagretduckbreasthalves',
#  'bonelessmoulardduckbreast',
#  'bonelessmoulardduckbreasthalves',
#  'bonelessmutton',
#  'bonelessporkchops',
#  'bonelessporkloinroast',
#  'bonelessporkshoulder',
#  'bonelessporkshoulderroast',
#  'bonelessporktenderloin',
#  'bonelesspotroast',
#  'bonelessribeyesteaks',
#  'bonelesssalmonfillets',
#  'bonelesssirloinsteak',
#  'bonelessskinlesschicken',
#  'bonelessskinlesschickenbreastcutlets',
#  'bonelessskinlesschickenbreasthalves',
#  'bonelessskinlesschickenbreasts',
#  'bonelessskinlesschickentenderloins',
#  'bonelessskinlesschickenthighs',
#  'bonelessskinlesssalmonfillets',
#  'bonelessskinlessthighs',
#  'bonelessskinlessturkeybreasts',
#  'bonelessskinonchickenthighs',
#  'bonelesssmokedtrout',
#  'bonelessturkeybreast',
#  'bonelessturkeybreasthalves',
#  'bonelessvealshoulder',
#  'bonelessvenisonsteak',
#  'bonesteak',
#  'bonito',
#  'bonitoflakes',
#  'borlottibeans',
#  'boscpears',
#  'bostonbutt',
#  'bostonlettuce',
#  'bottledchilisauce',
#  'bottledclamjuice',
#  'bottomround',
#  'bottomroundroast',
#  'bouillon',
#  'bouilloncube',
#  'bouillonpowder',
#  'bouillonshrimp',
#  'bouquet',
#  'bouquetgarni',
#  'bourbonwhiskey',
#  'boursin',
#  'bovrilpowder',
#  'bow',
#  'bows',
#  'boychoy',
#  'braeburnapple',
#  'braggsliquidaminos',
#  'braisingbeef',
#  'braisingsteak',
#  'bramleyapples',
#  'bran',
#  'brandy',
#  'branzini',
#  'bratbuns',
#  'braten',
#  'bratenfleisch',
#  'bratensaft',
#  'brats',
#  'bratwurstbuns',
#  'brazilnuts',
#  'bread',
#  'breadandbutterpickles',
#  'breadandbutterpickleslices',
#  'breadcrumbs',
#  'breaddough',
#  'breadflour',
#  'breadmachineyeast',
#  'breadrolls',
#  'breadstick',
#  'breakfastsausagelinks',
#  'breakfastsausages',
#  'brewedcoffee',
#  'briecheese',
#  'brine',
#  'brinecuredgreenolives',
#  'brioche',
#  'briochebread',
#  'briochebuns',
#  'brisket',
#  'broadbeans',
#  'broccoli',
#  'broccoliflorets',
#  'broccolini',
#  'broccolirabe',
#  'broccolislaw',
#  'brocolliflorets',
#  'broiler',
#  'broth',
#  'brownale',
#  'brownbasmatirice',
#  'brownbutter',
#  'browncardamom',
#  'brownchickenstock',
#  'browngravy',
#  'browngravymix',
#  'browning',
#  'brownlentils',
#  'brownmushroom',
#  'brownmustard',
#  'brownmustardseeds',
#  'brownrice',
#  'brownriceflour',
#  'brownricenoodles',
#  'brownricepasta',
#  'brownricesyrup',
#  'brownricevinegar',
#  'brownsauce',
#  'brownspread',
#  'brownsugar',
#  'brummel',
#  'bruschettatopping',
#  'brusselssprouts',
#  'bucatini',
#  'buckwheat',
#  'buckwheatflour',
#  'buckwheatnoodles',
#  'buckwheatsobanoodles',
#  'budweiserbeer',
#  'buffalomeat',
#  'buffalosauce',
#  'bulb',
#  'bulghur',
#  'bulgur',
#  'bulgurwheat',
#  'bulkitaliansausage',
#  'bull',
#  'buns',
#  'burdock',
#  'burgerbuns',
#  'burgerrolls',
#  'burgers',
#  'burgerstylecrumbles',
#  'burgundy',
#  'burgundywine',
#  'burrata',
#  'burritoseasoningmix',
#  'butter',
#  'butterbeans',
#  'buttercookingspray',
#  'buttercrackers',
#  'butterfish',
#  'butterlettuce',
#  'buttermilk',
#  'buttermilkbakingmix',
#  'buttermilkbiscuits',
#  'butternut',
#  'butternutsquash',
#  'butteroil',
#  'butterschmalz',
#  'buttonmushrooms',
#  'béchamelsauce',
#  'cabbage',
#  'cabbagehead',
#  'cabbageleaves',
#  'cabernetsauvignon',
#  'cabotchipotlecheddar',
#  'caesarsaladdressing',
#  'cagefreeeggs',
#  'cajunmeatseasoning',
#  'cajunseasoning',
#  'cake',
#  'cakeflour',
#  'cal',
#  'calamari',
#  'calamaristeak',
#  'calamataolives',
#  'calfliver',
#  'californiaavocado',
#  'californiabayleaves',
#  'californiachile',
#  'calimyrna',
#  'calimyrnafigs',
#  'calvados',
#  'calvesliver',
#  'camembert',
#  'campbell',
#  'canadianbacon',
#  'candiedginger',
#  'candiedlemonpeel',
#  'candiedwalnuts',
#  'candlenuts',
#  'canesugar',
#  'canesyrup',
#  'canevinegar',
#  'cannedbeans',
#  'cannedbeefbroth',
#  'cannedblackbeans',
#  'cannedcannellinibeans',
#  'cannedchicken',
#  'cannedchickenbroth',
#  'cannedchickpeas',
#  'cannedchoppedtomatoes',
#  'cannedcoconutmilk',
#  'cannedcorn',
#  'cannedlowsodiumchickenbroth',
#  'cannedpears',
#  'cannedsalmon',
#  'cannedsnails',
#  'cannedtomatoes',
#  'cannedtuna',
#  'cannedwholetomatoes',
#  'cannellinibeans',
#  'cannelloni',
#  'canola',
#  'canolamayonnaise',
#  'canolaoil',
#  'canolaoilcookingspray',
#  'cantaloupe',
#  'cantonnoodles',
#  'capellini',
#  'caperberries',
#  'capers',
#  'capocollo',
#  'capon',
#  'capsicum',
#  'caramels',
#  'caraway',
#  'carawaypowder',
#  'carawayseeds',
#  'carbonatedwater',
#  'cardamom',
#  'cardamompods',
#  'cardamomseeds',
#  'cardamon',
#  'carnarolirice',
#  'carnation',
#  'carneasada',
#  'carnitas',
#  'carrotcoleslaw',
#  'carrotgreens',
#  'carrotjuice',
#  'carrots',
#  'cashewbutter',
#  'cashewmilk',
#  'cashewnutpowder',
#  'cashewnuts',
#  'cassava',
#  'cassavarootflour',
#  'casserolesteak',
#  'cassiacinnamon',
#  'cassisjam',
#  'castelvetranoolives',
#  'caster',
#  'castersugar',
#  'castlecheese',
#  'catalinadressing',
#  'catfish',
#  'catfishfillets',
#  'catsup',
#  'caulfat',
#  'cauliflower',
#  'cauliflowerflorets',
#  'cauliflowerrice',
#  'cavatappi',
#  'cavatelli',
#  'cavendersgreekseasoning',
#  'cavolonero',
#  'cayenne',
#  'cayennepepper',
#  'cayennepeppersauce',
#  'celery',
#  'celeryflakes',
#  'celeryheart',
#  'celeryleaves',
#  'celerypowder',
#  'celeryribs',
#  'celeryroot',
#  'celerysalt',
#  'celeryseed',
#  'celerysticks',
#  'celticsalt',
#  'center',
#  'centercutbacon',
#  'centercutloinporkchop',
#  'centercutporkchops',
#  'centercutporkloinchops',
#  'centercutporkloinroast',
#  'centuryeggs',
#  'cep',
#  'cereal',
#  'cervelats',
#  'ceyloncinnamon',
#  'chaatmasala',
#  'chablis',
#  'challa',
#  'chamomile',
#  'champagne',
#  'champagnevinegar',
#  'champignon',
#  'chanadal',
#  'chanterelle',
#  'chard',
#  'chardonnay',
#  'charfillets',
#  'charsiu',
#  'charsiusauce',
#  'chateaubriand',
#  'chatmasala',
#  'chayotes',
#  'cheddarcheese',
#  'cheddarcheesesoup',
#  'cheehousauce',
#  'cheese',
#  'cheeseblend',
#  'cheesecubes',
#  'cheesecurds',
#  'cheeseravioli',
#  'cheesesauce',
#  'cheeseslices',
#  'cheesesoup',
#  'cheesespread',
#  'cheesetortellini',
#  'cheesmozzarellastick',
#  'cheesycheddar',
#  'chenpi',
#  'chermoula',
#  'chermoulapaste',
#  'cherries',
#  'cherrycoke',
#  'cherryjam',
#  'cherryjuice',
#  'cherrypreserves',
#  'cherrystoneclams',
#  'cherrytomatoes',
#  'chervil',
#  'chervilleaves',
#  'chestnuthoney',
#  'chestnutmushrooms',
#  'chestnuts',
#  'chexcereal',
#  'chiaseeds',
#  'chicharrónes',
#  'chicken',
#  'chickenandricesoup',
#  'chickenbase',
#  'chickenbones',
#  'chickenbouillon',
#  'chickenbouillongranules',
#  'chickenbreast',
#  'chickenbreastfillets',
#  'chickenbreasthalves',
#  'chickenbreasts',
#  'chickenbreaststrips',
#  'chickenbreasttenderloins',
#  'chickenbreasttenders',
#  'chickenbroth',
#  'chickencarcass',
#  'chickenconsomme',
#  'chickencookpre',
#  'chickencutlets',
#  'chickendemi',
#  'chickendrumsticks',
#  'chickenegg',
#  'chickenfeet',
#  'chickenfillets',
#  'chickenfingers',
#  'chickenflavorbouillon',
#  'chickenflavorbouillonpackets',
#  'chickenflavorbouillonpowder',
#  'chickenflavorbroccoli',
#  'chickenflavorricesides',
#  'chickenflavorstuffingmix',
#  'chickengizzards',
#  'chickengravy',
#  'chickengravygranules',
#  'chickengravymix',
#  'chickenheart',
#  'chickenlegquarters',
#  'chickenlegs',
#  'chickenliverpâté',
#  'chickenlivers',
#  'chickenmeat',
#  'chickennoodlesoup',
#  'chickennugget',
#  'chickenparts',
#  'chickenpatty',
#  'chickenpieces',
#  'chickensausage',
#  'chickenskins',
#  'chickensoupbase',
#  'chickenstock',
#  'chickenstockcubes',
#  'chickenstuffingmix',
#  'chickentenderloin',
#  'chickenthighfillets',
#  'chickenthighs',
#  'chickenwingdrummettes',
#  'chickenwings',
#  'chickpeaflour',
#  'chickpeas',
#  'chiffonade',
#  'chihuahuacheese',
#  'chikuwa',
#  'chileanseabass',
#  'chilebeanpaste',
#  'chiledearbol',
#  'chilegarlsauc',
#  'chilepaste',
#  'chilepastewithgarlic',
#  'chilepepper',
#  'chilepowder',
#  'chiles',
#  'chilesauce',
#  'chili',
#  'chilibeanpaste',
#  'chilibeans',
#  'chilibeansauce',
#  'chiliflakes',
#  'chiligarlicpaste',
#  'chilioil',
#  'chilipaste',
#  'chilipastewithgarlic',
#  'chilipepper',
#  'chilipepperflakes',
#  'chilipepperjam',
#  'chilipowder',
#  'chilisauce',
#  'chilischote',
#  'chiliseasoning',
#  'chillibeansauce',
#  'chillies',
#  'chillipaste',
#  'chillipulver',
#  'chimichurri',
#  'chinesebarbecuesauce',
#  'chineseblackmushrooms',
#  'chineseblackvinegar',
#  'chinesebuns',
#  'chinesecabbage',
#  'chinesecelery',
#  'chinesechilipaste',
#  'chinesechives',
#  'chinesecinnamon',
#  'chineseeggnoodles',
#  'chineseeggplants',
#  'chinesefive',
#  'chinesenoodles',
#  'chinesepeapods',
#  'chinesericevinegar',
#  'chinesericewine',
#  'chineseroastpork',
#  'chineserocksugar',
#  'chineserosewine',
#  'chinesesausage',
#  'chineseturnip',
#  'chinkiangvinegar',
#  'chipolatasausage',
#  'chipotle',
#  'chipotlechile',
#  'chipotlechilepowder',
#  'chipotlepaste',
#  'chipotlepeppers',
#  'chipotlesalsa',
#  'chipotlesauce',
#  'chipotleseasoning',
#  'chipotlesinadobo',
#  'chiveflowers',
#  'chives',
#  'chobaniyogurt',
#  'chole',
#  'cholent',
#  'chopgreenchilies',
#  'choppedalmonds',
#  'choppedbacon',
#  'choppedbellpepper',
#  'choppedcelery',
#  'choppedcilantro',
#  'choppedcookedham',
#  'choppedcoriander',
#  'choppedfreshchives',
#  'choppedfreshcilantro',
#  'choppedfreshherbs',
#  'choppedfreshmint',
#  'choppedfreshsage',
#  'choppedfreshthyme',
#  'choppedgarlic',
#  'choppedgreenbellpepper',
#  'choppedgreenchiles',
#  'choppedgreenchilies',
#  'choppedham',
#  'choppedhazelnuts',
#  'choppedkale',
#  'choppedleaves',
#  'choppednuts',
#  'choppedonion',
#  'choppedparsley',
#  'choppedpecans',
#  'choppedpotatoes',
#  'choppedtomatoes',
#  'choppedwalnuts',
#  'chorizo',
#  'chorizosausage',
#  'chourico',
#  'chowmeinnoodles',
#  'choysum',
#  'christopherranchgarlic',
#  'chrysanthemumleaves',
#  'chuck',
#  'chuckeye',
#  'chuckeyesteak',
#  'chuckroast',
#  'chucksteaks',
#  'chunkwhitetuna',
#  'chunkyhotsalsa',
#  'chunkymediumsalsa',
#  'chunkymildsalsa',
#  'chunkypastasauce',
#  'chunkypeanutbutter',
#  'chunkysalsa',
#  'chunkytomatoes',
#  'chunkytomatosalsa',
#  'chunkytomatosauce',
#  'chunosauce',
#  'chutney',
#  'chèvre',
#  'ciabatta',
#  'ciabattabread',
#  'ciabattabuns',
#  'ciabattaloaf',
#  'ciabattarolls',
#  'cider',
#  'cidervinegar',
#  'cilantro',
#  'cilantroleaves',
#  'cilantropesto',
#  'cilantroroot',
#  'cilantrosprigs',
#  'cilantrostems',
#  'cinnamon',
#  'cinnamonsticks',
#  'cipollinionions',
#  'cippolinionions',
#  'citrus',
#  'citrusfruit',
#  'citrusjuice',
#  'citrusleaves',
#  'clabber',
#  'clamjuice',
#  'clams',
#  ...]
